# %%
from guardrails import Guard
from guardrails_ai.response_evaluator import ResponseEvaluator
from dotenv import load_dotenv

# %%
# load the env vars
load_dotenv()
# Out:
# True

# %%
# create the validator
validator = ResponseEvaluator(llm_callable="gpt-5-mini",
                              on_fail="noop")

# create guard and add the validator to the guard
guard = Guard().use(validator)

# %%
# validate the user input

user_query = "What is the capital of India?"

llm_response_1 = "The capital of India is New Delhi."
llm_response_2 = "India is known for its rich history and culture. It has a city with large metro rail network and is one of the most populous cities in the world."

response_1 = guard.validate(llm_response_1, 
                            metadata={"validation_question": user_query})
# Out:
# /home/rikesh/Rikesh/RAG/.venv/lib/python3.12/site-packages/guardrails/validator_service/__init__.py:81: UserWarning: Could not obtain an event loop. Falling back to synchronous validation.
#   warnings.warn(
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno -2] Name or service not known)")) encountered while exporting span batch, retrying in 1.09s.

# %%
response_1
# Out:
# ValidationOutcome[TypeVar](call_id='127598367965664', raw_llm_output='The capital of India is New Delhi.', validation_summaries=[], validated_output='The capital of India is New Delhi.', reask=None, validation_passed=True, error=None)

# %%
print(f"Validation Result: {response_1.validation_passed}")
print(f"Raw User Input: {response_1.raw_llm_output}")
print(f"Validated Output: {response_1.validated_output}")
# Out:
# Validation Result: True
# Raw User Input: The capital of India is New Delhi.
# Validated Output: The capital of India is New Delhi.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno -2] Name or service not known)")) encountered while exporting span batch, retrying in 2.03s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno -2] Name or service not known)")) encountered while exporting span batch, retrying in 3.71s.

# %%
response_2 = guard.validate(llm_response_2, 
                            metadata={"validation_question": user_query})
# Out:
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.

# %%
response_2
# Out:
# ValidationOutcome[TypeVar](call_id='127598346819680', raw_llm_output='India is known for its rich history and culture. It has a city with large metro rail network and is one of the most populous cities in the world.', validation_summaries=[ValidationSummary(validator_name='ResponseEvaluator', validator_status='fail', property_path='$', failure_reason="The LLM says 'No'. The validation failed.", error_spans=None)], validated_output='India is known for its rich history and culture. It has a city with large metro rail network and is one of the most populous cities in the world.', reask=None, validation_passed=False, error=None)

# %%
print(f"Validation Result: {response_2.validation_passed}")
print(f"Raw User Input: {response_2.raw_llm_output}")
print(f"Validated Output: {response_2.validated_output}")
# Out:
# Validation Result: False
# Raw User Input: India is known for its rich history and culture. It has a city with large metro rail network and is one of the most populous cities in the world.
# Validated Output: India is known for its rich history and culture. It has a city with large metro rail network and is one of the most populous cities in the world.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno -2] Name or service not known)")) encountered while exporting span batch, retrying in 0.86s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno -2] Name or service not known)")) encountered while exporting span batch, retrying in 1.85s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno -2] Name or service not known)")) encountered while exporting span batch, retrying in 4.33s.
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.
